# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine


sns.set(style='whitegrid')

# %%
# Replace with your connection string
engine = create_engine('postgresql://sy91dhb:g5t49ao@178.156.142.230:5432/hd64m1ki')

# Load a sample of the data make sure that it is only story values as other types are irrelevant
query = '''
SELECT *
FROM hacker_news.items
WHERE type = 'story'
LIMIT 10000;
'''

df = pd.read_sql(query, engine)

# Preview the data
df.head()
# Out:
#          id  dead   type        by                time  text parent  \
# 0  29952713  None  story      None 2022-01-16 02:32:22  None   None
# 1  29952716  None  story    pacaro 2022-01-16 02:33:04  None   None
# 2  29404048  None  story     ingve 2021-12-01 14:45:47  None   None
# 3  29404055  None  story    yujian 2021-12-01 14:46:22  None   None
# 4  29404063  None  story  barbacoa 2021-12-01 14:46:53  None   None
#
#                    kids                                                url  \
# 0                  None                                               None
# 1            [29953456]  https://www.tomshardware.com/news/raspberry-pi...
# 2                  None                   https://cliffle.com/p/dangerust/
# 3                  None  https://pythonalgos.com/2021/12/01/summarized-...
# 4  [29404796, 29405720]  https://bariweiss.substack.com/p/twitter-is-ab...
#
#    score                                              title  descendants
# 0    NaN                                               None          NaN
# 1    7.0  RISC-V Powered Mango Pi Takes on Raspberry Pi ...          1.0
# 2    2.0                       Learn Rust the Dangerous Way          0.0
# 3    2.0      November 2021 in Headlines – Summarized by AI          0.0
# 4   29.0                  Twitter Is About to Get Way Worse          7.0

# %%
# Sort the entire DataFrame by 'score' in descending order and show top 10
top_10_scored_items = df.sort_values('score', ascending=False).head(10)

# Display the result
top_10_scored_items
# Out:
#             id  dead   type               by                time  text parent  \
# 2245  27199330  None  story              ra7 2021-05-18 19:54:06  None   None
# 4681  27996684  None  story      andreareina 2021-07-29 15:04:34  None   None
# 7603  29255511  None  story           kdavis 2021-11-17 16:54:03  None   None
# 5905  28096019  None  story         yewenjie 2021-08-07 06:36:52  None   None
# 7391  30352772  None  story       nycdatasci 2022-02-15 21:10:56  None   None
# 1337  27199225  None  story     todsacerdoti 2021-05-18 19:47:00  None   None
# 7728  29554461  None  story             dynm 2021-12-14 17:34:37  None   None
# 1493  30651720  None  story             dynm 2022-03-12 14:47:41  None   None
# 8850  31052029  None  story        marcthe12 2022-04-16 14:11:28  None   None
# 9604  28541117  None  story  andrewnicolalde 2021-09-15 17:26:05  None   None
#
#                                                    kids  \
# 2245  [27199477, 27201715, 27201371, 27201343, 27200...
# 4681  [27998894, 27998150, 27998913, 27998677, 28000...
# 7603  [29256289, 29256924, 29260811, 29258352, 29256...
# 5905  [28096722, 28096776, 28096954, 28097304, 28098...
# 7391  [30353413, 30353057, 30353917, 30355077, 30354...
# 1337  [27200092, 27202919, 27201373, 27203032, 27205...
# 7728  [29558847, 29560283, 29558215, 29558521, 29558...
# 1493  [30651975, 30651950, 30653782, 30651954, 30651...
# 8850  [31052234, 31052321, 31052221, 31052319, 31053...
# 9604  [28541902, 28542004, 28541667, 28541699, 28543...
#
#                                                     url   score  \
# 2245  https://blog.google/technology/research/projec...  1339.0
# 4681  https://stackoverflow.blog/2021/07/28/700000-l...  1130.0
# 7603  https://crystalverse.com/sodium-chloride-cryst...  1119.0
# 5905  https://github.com/nadimkobeissi/appleprivacyl...  1082.0
# 7391  https://www.akamai.com/newsroom/press-release/...   986.0
# 1337   https://blog.thea.codes/winterblooms-tech-stack/   925.0
# 7728                       https://dynomight.net/plans/   846.0
# 1493                    https://dynomight.net/teaching/   801.0
# 8850          https://github.com/ziglang/zig/pull/11442   752.0
# 9604  https://www.justice.gov/opa/pr/three-former-us...   743.0
#
#                                                   title  descendants  \
# 2245  Project Starline: Feel like you're there, toge...        511.0
# 4681                        How Dwarf Fortress is built        388.0
# 7603       How to grow sodium chloride crystals at home        180.0
# 5905  An open letter against Apple's new privacy-inv...        430.0
# 7391                           Akamai to Acquire Linode        326.0
# 1337  The tools and tech I use to run a one-woman ha...        130.0
# 7728            Plans you're not supposed to talk about        635.0
# 1493  Teaching is a slow process of becoming everyth...        489.0
# 8850  Zig self hosted compiler is now capable of bui...        274.0
# 9604  Three ex-US intelligence officers admit hackin...        237.0
#
#       title_length            datetime  hour
# 2245            50 2021-05-18 19:54:06    19
# 4681            27 2021-07-29 15:04:34    15
# 7603            44 2021-11-17 16:54:03    16
# 5905            80 2021-08-07 06:36:52     6
# 7391            24 2022-02-15 21:10:56    21
# 1337            60 2021-05-18 19:47:00    19
# 7728            39 2021-12-14 17:34:37    17
# 1493            58 2022-03-12 14:47:41    14
# 8850            58 2022-04-16 14:11:28    14
# 9604            55 2021-09-15 17:26:05    17

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           10000 non-null  int64
#  1   dead         2149 non-null   object
#  2   type         10000 non-null  object
#  3   by           9737 non-null   object
#  4   time         10000 non-null  datetime64[ns]
#  5   text         684 non-null    object
#  6   parent       0 non-null      object
#  7   kids         3189 non-null   object
#  8   url          8299 non-null   object
#  9   score        9737 non-null   float64
#  10  title        8835 non-null   object
#  11  descendants  7721 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 937.6+ KB
# id                 0
# dead            7851
# type               0
# by               263
# time               0
# text            9316
# parent         10000
# kids            6811
# url             1701
# score            263
# title           1165
# descendants     2279
# dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['score'], bins=100, kde=True)
plt.title("Score Distribution")
plt.xlabel("Score")
plt.ylabel("Count")
plt.show()

# %%
df['title_length'] = df['title'].fillna('').apply(len)
df['datetime'] = pd.to_datetime(df['time'], unit='s')

# Correlations
df[['score', 'descendants', 'title_length']].corr()
# Out:
#                  score  descendants  title_length
# score         1.000000     0.799079      0.041208
# descendants   0.799079     1.000000      0.002921
# title_length  0.041208     0.002921      1.000000

# %%
print(df.columns)
# Out:
# Index(['id', 'dead', 'type', 'by', 'time', 'text', 'parent', 'kids', 'url',
#        'score', 'title', 'descendants', 'title_length', 'datetime'],
#       dtype='object')

# %%
# Top authors by post count
df['by'].value_counts().head(10)

# Top authors by average score
df.groupby('by')['score'].mean().sort_values(ascending=False).head(10)
# Out:
# by
# andreareina        1130.0
# kdavis             1119.0
# yewenjie           1082.0
# nycdatasci          986.0
# marcthe12           752.0
# andrewnicolalde     743.0
# krstffr             701.0
# ipnon               694.0
# angrymouse          681.0
# jillesvangurp       677.0
# Name: score, dtype: float64

# %%
# Top authors by score count
df['by'].value_counts().head(10)

# Top authors by average score
df.groupby('by')['score'].mean().sort_values(ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 5
#       2 df['by'].value_counts().head(10)
#       4 # Top authors by average score
# ----> 5 df.groupby('by')['score'].sort_values(ascending=False).head(10)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'sort_values'

# %%
# Plot all post scores for a few of these high scoring authors to see if they consistently score highly
# andreareina

# %%
# nycdatasci

# %%
# angrymouse

# %%
# Post frequency by hour of day
df['hour'] = df['datetime'].dt.hour
sns.barplot(x='hour', y='score', data=df)
plt.title("Avg Score by Hour of Day")
plt.show()

# %%
# Null authors or titles
print("Missing authors:", df['by'].isnull().sum())
print("Missing titles:", df['title'].isnull().sum())
print("Missing scores:", df['score'].isnull().sum())

# Stories with 0 score
df[df['score'] == 0].head()

# Outliers
df[df['score'] > 1000].sort_values('score', ascending=False).head()
# Out:
# Missing authors: 263
# Missing titles: 1165
# Missing scores: 263
#             id  dead   type           by                time  text parent  \
# 2245  27199330  None  story          ra7 2021-05-18 19:54:06  None   None
# 4681  27996684  None  story  andreareina 2021-07-29 15:04:34  None   None
# 7603  29255511  None  story       kdavis 2021-11-17 16:54:03  None   None
# 5905  28096019  None  story     yewenjie 2021-08-07 06:36:52  None   None
#
#                                                    kids  \
# 2245  [27199477, 27201715, 27201371, 27201343, 27200...
# 4681  [27998894, 27998150, 27998913, 27998677, 28000...
# 7603  [29256289, 29256924, 29260811, 29258352, 29256...
# 5905  [28096722, 28096776, 28096954, 28097304, 28098...
#
#                                                     url   score  \
# 2245  https://blog.google/technology/research/projec...  1339.0
# 4681  https://stackoverflow.blog/2021/07/28/700000-l...  1130.0
# 7603  https://crystalverse.com/sodium-chloride-cryst...  1119.0
# 5905  https://github.com/nadimkobeissi/appleprivacyl...  1082.0
#
#                                                   title  descendants  \
# 2245  Project Starline: Feel like you're there, toge...        511.0
# 4681                        How Dwarf Fortress is built        388.0
# 7603       How to grow sodium chloride crystals at home        180.0
# 5905  An open letter against Apple's new privacy-inv...        430.0
#
#       title_length            datetime  hour
# 2245            50 2021-05-18 19:54:06    19
# 4681            27 2021-07-29 15:04:34    15
# 7603            44 2021-11-17 16:54:03    16
# 5905            80 2021-08-07 06:36:52     6

# %%
df['dead'].value_counts(dropna=False)
# Out:
# dead
# None    7851
# True    2149
# Name: count, dtype: int64

# %%
# Sort dead items by score in ascending order and show top 10
dead_items_sorted = dead_items.sort_values('score', ascending=False)
dead_items_sorted.head(10)
# Out:
#             id  dead   type               by                time  \
# 9845  27997204  True  story              ktr 2021-07-29 15:49:42
# 4889  29305214  True  story       ourmandave 2021-11-22 11:21:39
# 9063  30103414  True  story  wallopingfuture 2022-01-27 17:33:11
# 2243  32000288  True  story             bane 2022-07-06 14:09:07
# 3649  27847428  True  story    handheldmouse 2021-07-15 18:36:32
# 7878  26748990  True  story        MobileVet 2021-04-09 12:09:21
# 1463  26998765  True  story         Afforess 2021-04-30 21:19:39
# 6000  28195939  True  story      apollinaire 2021-08-16 09:01:50
# 4703  30602114  True  story        lauriswtf 2022-03-08 16:50:20
# 2287  27398149  True  story          jostmey 2021-06-04 20:38:17
#
#                                                    text parent  \
# 9845                                               None   None
# 4889                                               None   None
# 9063                                               None   None
# 2243                                               None   None
# 3649  Hi HN,<p>We are Alex and Daniel, the founders ...   None
# 7878                                               None   None
# 1463                                               None   None
# 6000                                               None   None
# 4703                                               None   None
# 2287                                               None   None
#
#                                           kids  \
# 9845                      [27997809, 27997722]
# 4889            [29326435, 29326663, 29326678]
# 9063  [30103947, 30103982, 30104072, 30104053]
# 2243            [32003408, 32001087, 32003858]
# 3649            [27848458, 27848442, 27848631]
# 7878            [26749023, 26749010, 26749273]
# 1463                                [26998906]
# 6000                                      None
# 4703  [30602633, 30602962, 30602693, 30602652]
# 2287                      [27398253, 27398211]
#
#                                                     url  score  \
# 9845  http://journal.stuffwithstuff.com/2021/07/29/6...   30.0
# 4889  https://barleymowchiswick.com/how-to-hide-from...   30.0
# 9063                                               None   28.0
# 2243                                               None   24.0
# 3649                                               None   23.0
# 7878             https://www.bbc.co.uk/news/uk-11437314   21.0
# 1463  https://www.vice.com/en/article/wx58vx/basecam...   21.0
# 6000  https://www.lrb.co.uk/the-paper/v43/n16/lydia-...   20.0
# 4703                                               None   17.0
# 2287  https://duckduckgo.com/?q=tank+man&t=h_&iax=im...   17.0
#
#                                                   title  descendants  \
# 9845    Crafting Interpreters Available in Print or PDF          NaN
# 4889  How to hide from a drone – the subtle art of g...          NaN
# 9063                                               None          NaN
# 2243                                               None          NaN
# 3649  Launch HN: Zen (YC S21) – Posture correction s...          NaN
# 7878                     Prince Philip has died aged 99          NaN
# 1463  Basecamp Employees Are Leaving After CEO Bans ...          NaN
# 6000                                    One French City          NaN
# 4703                                               None          NaN
# 2287    There are no results for tank man on DuckDuckGo          NaN
#
#       title_length            datetime  hour
# 9845            47 2021-07-29 15:49:42    15
# 4889            80 2021-11-22 11:21:39    11
# 9063             0 2022-01-27 17:33:11    17
# 2243             0 2022-07-06 14:09:07    14
# 3649            77 2021-07-15 18:36:32    18
# 7878            30 2021-04-09 12:09:21    12
# 1463            62 2021-04-30 21:19:39    21
# 6000            15 2021-08-16 09:01:50     9
# 4703             0 2022-03-08 16:50:20    16
# 2287            47 2021-06-04 20:38:17    20

# %%
# top URLs by post count

# %%
# top URLs by score count
